# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Load the data into a Pandas DataFrame
df = pd.read_csv('result100.dat', delim_whitespace=True, header=None, names=['x', 'y', 'z'])

# Show the first few rows of the DataFrame to ensure data is loaded correctly
df.head()
# Out:
#          x         y         z
# 0  1.30881 -0.404863 -0.336000
# 1  1.31862 -0.371686 -0.307717
# 2  1.32758 -0.338273 -0.279434
# 3  1.33570 -0.304644 -0.251152
# 4  1.34297 -0.270821 -0.222869

# %%
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D curve using the DataFrame columns
ax.plot(df['x'], df['y'], df['z'])

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
ax.set_title('Helix Plot 100 Intervals')
# Out:
# Text(0.5, 0.92, 'Helix Plot 100 Intervals')

# %%
# Load the data into a Pandas DataFrame
df1 = pd.read_csv('result100.dat', delim_whitespace=True, header=None, names=['x', 'y', 'z'])

# Show the first few rows of the DataFrame to ensure data is loaded correctly
df1.head()
# Out:
#          x         y         z
# 0  1.30881 -0.404863 -0.336000
# 1  1.31862 -0.371686 -0.307717
# 2  1.32758 -0.338273 -0.279434
# 3  1.33570 -0.304644 -0.251152
# 4  1.34297 -0.270821 -0.222869

# %%
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D curve using the DataFrame columns
ax.plot(df1['x'], df1['y'], df1['z'])

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
ax.set_title('Helix Plot 1 Interval')
# Out:
# Text(0.5, 0.92, 'Helix Plot 1 Interval')
